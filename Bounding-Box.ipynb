# %%
import pandas as pd
import folium
# Out:
# /Users/thilina/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('OCM_Extracted_Data/central_london_ocm_final_data.csv')
df
# Out:
#       Place_ID                    Operator Bussiness_Status  \
# 0       279058              POD Point (UK)      Operational
# 1       201812              POD Point (UK)      Operational
# 2       157331                        Lidl      Operational
# 3       285436              Connected Kerb          Unknown
# 4        15833  Business Owner at Location      Operational
# ...        ...                         ...              ...
# 8456    155345               BP Pulse (UK)      Operational
# 8457    214489                 ChargePoint          Unknown
# 8458    299340             Osprey Charging      Operational
# 8459    259855             Osprey Charging      Operational
# 8460    136592               BP Pulse (UK)          Unknown
#
#                           Location_Name  \
# 0                       Nordic Wood LTD
# 1                Tesco Extra-Brooklands
# 2                       Lidl-Brooklands
# 3                     High Road Byfleet
# 4                     RHS Garden Wisley
# ...                                 ...
# 8456                    Harvester Grays
# 8457        SERVICE STN BASILDON PETROL
# 8458                Brentwood Town Hall
# 8459  Brentwood Town Hall - AC charging
# 8460           Greater Anglia Trains 13
#
#                                                 Address   Latitude  Longitude  \
# 0                            Nordic Wood LTD,  KT14 7JL  51.345567  -0.483448
# 1              Barnes Wallis Drive, Weybridge, KT13 0XF  51.344469  -0.475963
# 2     The Paddocks Retail Park, Sopwith Drive, KT13 0XR  51.345411  -0.473583
# 3         High Road Byfleet Car Park, Byfleet, KT14 7QS  51.339220  -0.474253
# 4                                      Woking, GU23 6QB  51.313984  -0.472872
# ...                                                 ...        ...        ...
# 8456            Arterial Road A1306, Thurrock, RM16 6UT  51.494279   0.304085
# 8457                       A127, Great Warley, CM13 3ES  51.574770   0.313379
# 8458                  Ingrave Road, Brentwood, CM15 8AY  51.618801   0.307254
# 8459                  Ingrave Road, Brentwood, CM15 8AY  51.617852   0.308136
# 8460                   Hutton Road, Brentwood, CM15 8JD  51.630290   0.328535
#
#                              Usage  Number_of_Connectors  Min_Power_kW  \
# 0     Public - Membership Required                     1           7.0
# 1     Public - Membership Required                     4           7.0
# 2     Public - Membership Required                     3          22.0
# 3                           Public                     2          22.0
# 4                           Public                     2           3.0
# ...                            ...                   ...           ...
# 8456      Public - Pay At Location                     3          43.0
# 8457                        Public                     2          22.0
# 8458      Public - Pay At Location                     3          22.0
# 8459      Public - Pay At Location                     6          11.0
# 8460  Public - Membership Required                     2           7.0
#
#       Max_Power_kW Max_Charging_Type Rapid_Charge_Available  \
# 0              7.0              Fast                     No
# 1             50.0             Rapid                    Yes
# 2             50.0             Rapid                    Yes
# 3             22.0              Fast                     No
# 4              7.0              Fast                     No
# ...            ...               ...                    ...
# 8456          50.0             Rapid                    Yes
# 8457          22.0              Fast                     No
# 8458          50.0             Rapid                    Yes
# 8459          11.0              Fast                     No
# 8460           7.0              Fast                     No
#
#      Fast_Charge_Available Slow_Charge_Available
# 0                      Yes                    No
# 1                      Yes                    No
# 2                      Yes                    No
# 3                      Yes                    No
# 4                      Yes                   Yes
# ...                    ...                   ...
# 8456                    No                    No
# 8457                   Yes                    No
# 8458                   Yes                    No
# 8459                   Yes                    No
# 8460                   Yes                    No
#
# [8461 rows x 15 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.columns
# Out:
# Index(['Place_ID', 'Operator', 'Bussiness_Status', 'Location_Name', 'Address',
#        'Latitude', 'Longitude', 'Usage', 'Number_of_Connectors',
#        'Min_Power_kW', 'Max_Power_kW', 'Max_Charging_Type',
#        'Rapid_Charge_Available', 'Fast_Charge_Available',
#        'Slow_Charge_Available'],
#       dtype='object')

# %%
df.shape
# Out:
# (8461, 15)

# %%
## Bounding box coordinates
MIN_LAT, MAX_LAT = 51.48, 51.55
MIN_LNG, MAX_LNG = -0.20, -0.02

## Center of the bounding box
center_lat = (MIN_LAT + MAX_LAT) / 2
center_lng = (MIN_LNG + MAX_LNG) / 2

m = folium.Map(location=[center_lat, center_lng], zoom_start=13)
folium.Rectangle(
    bounds=[[MIN_LAT, MIN_LNG], [MAX_LAT, MAX_LNG]],
    color='blue',
    fill=False,
    weight=2
).add_to(m)

folium.Marker(
    [center_lat, center_lng],
    popup='Center',
    icon=folium.Icon(color='red')
).add_to(m)


folium.Circle(
    location=[center_lat, center_lng],
    color='green',
    fill=True,
    fill_opacity=0.2,
).add_to(m)

m.save("central_london_map.html")

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd1e51d71ff4b0bdc01e107a9e7842b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd1e51d71ff4b0bdc01e107a9e7842b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd1e51d71ff4b0bdc01e107a9e7842b2 = L.map(
#                 &quot;map_fd1e51d71ff4b0bdc01e107a9e7842b2&quot;,
#                 {
#                     center: [51.515, -0.11],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9580f73115be27412d890f4da543112 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e9580f73115be27412d890f4da543112.addTo(map_fd1e51d71ff4b0bdc01e107a9e7842b2);
#
#
#             var rectangle_f96e6bce18366b28f15347270a7effbf = L.rectangle(
#                 [[51.48, -0.2], [51.55, -0.02]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_fd1e51d71ff4b0bdc01e107a9e7842b2);
#
#
#             var marker_dba96eee22d9425a143d0dad86a71d76 = L.marker(
#                 [51.515, -0.11],
#                 {
# }
#             ).addTo(map_fd1e51d71ff4b0bdc01e107a9e7842b2);
#
#
#             var icon_848df17288c40178e97faca7e508d3d9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_db9f9908848627feb089371dbad72c6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24b84526ea9f4f9ddd6c4fb1b4d9d122 = $(`&lt;div id=&quot;html_24b84526ea9f4f9ddd6c4fb1b4d9d122&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Center&lt;/div&gt;`)[0];
#                 popup_db9f9908848627feb089371dbad72c6c.setContent(html_24b84526ea9f4f9ddd6c4fb1b4d9d122);
#
#
#
#         marker_dba96eee22d9425a143d0dad86a71d76.bindPopup(popup_db9f9908848627feb089371dbad72c6c)
#         ;
#
#
#
#
#                 marker_dba96eee22d9425a143d0dad86a71d76.setIcon(icon_848df17288c40178e97faca7e508d3d9);
#
#
#             var circle_bbd5277aa90b0edca2ededa01f227fcd = L.circle(
#                 [51.515, -0.11],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fd1e51d71ff4b0bdc01e107a9e7842b2);
#
#
#             tile_layer_e9580f73115be27412d890f4da543112.addTo(map_fd1e51d71ff4b0bdc01e107a9e7842b2);
#
#
#                 marker_dba96eee22d9425a143d0dad86a71d76.setIcon(icon_848df17288c40178e97faca7e508d3d9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
