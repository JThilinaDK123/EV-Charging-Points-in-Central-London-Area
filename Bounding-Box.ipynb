# %%
import pandas as pd
import folium
# Out:
# /Users/thilina/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('OCM_Extracted_Data/central_london_ocm_final_data.csv')
df
# Out:
#       Place_ID                       Operator Bussiness_Status  \
# 0       157861                        Unknown          Unknown
# 1        77351            Total Energies (UK)      Operational
# 2       252197    SureCharge (FM Conway) (UK)          Unknown
# 3       252184    SureCharge (FM Conway) (UK)          Unknown
# 4       252205    SureCharge (FM Conway) (UK)          Unknown
# ...        ...                            ...              ...
# 3054    214410  Shell Recharge Solutions (UK)          Unknown
# 3055     56889            Total Energies (UK)      Operational
# 3056    264752  Shell Recharge Solutions (UK)          Unknown
# 3057    214375  Shell Recharge Solutions (UK)          Unknown
# 3058     72436                 POD Point (UK)          Unknown
#
#                              Location_Name  \
# 0                                  4002063
# 1                                Farm Lane
# 2                              Knivet Road
# 3                             Eustace Road
# 4                              Knivet Road
# ...                                    ...
# 3054             Shell Recharge/Ubitricity
# 3055                  "Here East" Car Park
# 3056                                  opp.
# 3057             Shell Recharge/Ubitricity
# 3058  Mossbourne Riverside Primary Academy
#
#                                                 Address   Latitude  Longitude  \
# 0     Level B – Fulham Broadway Car Park, Fulham Roa...  51.480316  -0.194363
# 1                         10 Farm Lane, LONDON, SW6 1PS  51.481311  -0.197749
# 2                     Knivet Road, Hammersmith, SW6 1JH  51.482640  -0.198470
# 3                    Eustace Road, Hammersmith, SW6 1JB  51.482240  -0.199260
# 4                     Knivet Road, Hammersmith, SW6 1JH  51.483060  -0.198830
# ...                                                 ...        ...        ...
# 3054                               null, London, E9 5HW  51.549702  -0.029318
# 3055                     Waterden Road, London, E15 2EE  51.549023  -0.023651
# 3056                               opp., London, E9 5NH  51.546903  -0.028677
# 3057                               null, London, E3 2NU  51.540219  -0.023026
# 3058      Queen Elizabeth Olympic Park, London, E15 2EE  51.545833  -0.022222
#
#                                            Usage  Number_of_Connectors  \
# 0                                         Public                     1
# 1                   Public - Membership Required                     2
# 2                   Public - Membership Required                     1
# 3                   Public - Membership Required                     1
# 4                   Public - Membership Required                     1
# ...                                          ...                   ...
# 3054                    Public - Pay At Location                     1
# 3055                Public - Membership Required                     1
# 3056                    Public - Pay At Location                     1
# 3057                    Public - Pay At Location                     1
# 3058  Private - For Staff, Visitors or Customers                     1
#
#       Min_Power_kW  Max_Power_kW Max_Charging_Type Rapid_Charge_Available  \
# 0             22.0          22.0              Fast                     No
# 1              4.0           7.0              Fast                     No
# 2              4.8           4.8              Slow                     No
# 3              4.8           4.8              Slow                     No
# 4              4.8           4.8              Slow                     No
# ...            ...           ...               ...                    ...
# 3054           5.0           5.0              Slow                     No
# 3055           7.0           7.0              Fast                     No
# 3056           5.0           5.0              Slow                     No
# 3057           5.0           5.0              Slow                     No
# 3058           7.0           7.0              Fast                     No
#
#      Fast_Charge_Available Slow_Charge_Available
# 0                      Yes                    No
# 1                      Yes                   Yes
# 2                       No                   Yes
# 3                       No                   Yes
# 4                       No                   Yes
# ...                    ...                   ...
# 3054                    No                   Yes
# 3055                   Yes                    No
# 3056                    No                   Yes
# 3057                    No                   Yes
# 3058                   Yes                    No
#
# [3059 rows x 15 columns]

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df[df.duplicated(keep=False)]
# Out:
#       Place_ID                       Operator Bussiness_Status  \
# 1575    264616  Shell Recharge Solutions (UK)          Unknown
# 1634    264616  Shell Recharge Solutions (UK)          Unknown
# 1730    252576  Shell Recharge Solutions (UK)          Unknown
# 1751    252576  Shell Recharge Solutions (UK)          Unknown
#
#                   Location_Name                             Address  Latitude  \
# 1575  Shell Recharge/Ubitricity              null, London, SW1V 2NS     51.49
# 1634  Shell Recharge/Ubitricity              null, London, SW1V 2NS     51.49
# 1730           o/s Wilkie House  o/s Wilkie House, London, SW1P 4EH     51.49
# 1751           o/s Wilkie House  o/s Wilkie House, London, SW1P 4EH     51.49
#
#       Longitude                     Usage  Number_of_Connectors  Min_Power_kW  \
# 1575   -0.13820  Public - Pay At Location                     1           5.0
# 1634   -0.13820  Public - Pay At Location                     1           5.0
# 1730   -0.12994  Public - Pay At Location                     1           5.0
# 1751   -0.12994  Public - Pay At Location                     1           5.0
#
#       Max_Power_kW Max_Charging_Type Rapid_Charge_Available  \
# 1575           5.0              Slow                     No
# 1634           5.0              Slow                     No
# 1730           5.0              Slow                     No
# 1751           5.0              Slow                     No
#
#      Fast_Charge_Available Slow_Charge_Available
# 1575                    No                   Yes
# 1634                    No                   Yes
# 1730                    No                   Yes
# 1751                    No                   Yes

# %%
df = df.drop_duplicates(keep='last')

# %%
df.columns
# Out:
# Index(['Place_ID', 'Operator', 'Bussiness_Status', 'Location_Name', 'Address',
#        'Latitude', 'Longitude', 'Usage', 'Number_of_Connectors',
#        'Min_Power_kW', 'Max_Power_kW', 'Max_Charging_Type',
#        'Rapid_Charge_Available', 'Fast_Charge_Available',
#        'Slow_Charge_Available'],
#       dtype='object')

# %%
df.shape
# Out:
# (3057, 15)

# %%
## Bounding box coordinates
MIN_LAT, MAX_LAT = 51.48, 51.55
MIN_LNG, MAX_LNG = -0.20, -0.02

## Center of the bounding box
center_lat = (MIN_LAT + MAX_LAT) / 2
center_lng = (MIN_LNG + MAX_LNG) / 2

m = folium.Map(location=[center_lat, center_lng], zoom_start=13)
folium.Rectangle(
    bounds=[[MIN_LAT, MIN_LNG], [MAX_LAT, MAX_LNG]],
    color='blue',
    fill=False,
    weight=2
).add_to(m)

folium.Marker(
    [center_lat, center_lng],
    popup='Center',
    icon=folium.Icon(color='red')
).add_to(m)


folium.Circle(
    location=[center_lat, center_lng],
    color='green',
    fill=True,
    fill_opacity=0.2,
).add_to(m)

m.save("central_london_map.html")

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a793e46dc471d5b2b9528835ce7ca88a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a793e46dc471d5b2b9528835ce7ca88a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a793e46dc471d5b2b9528835ce7ca88a = L.map(
#                 &quot;map_a793e46dc471d5b2b9528835ce7ca88a&quot;,
#                 {
#                     center: [51.515, -0.11],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b1b1791910e07b9fd75dd3a8cd34737 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b1b1791910e07b9fd75dd3a8cd34737.addTo(map_a793e46dc471d5b2b9528835ce7ca88a);
#
#
#             var rectangle_3fa719afe3911d3c2ebe86f0905ed0c3 = L.rectangle(
#                 [[51.48, -0.2], [51.55, -0.02]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_a793e46dc471d5b2b9528835ce7ca88a);
#
#
#             var marker_96fad15a2a1313c05a3e14d45f351729 = L.marker(
#                 [51.515, -0.11],
#                 {
# }
#             ).addTo(map_a793e46dc471d5b2b9528835ce7ca88a);
#
#
#             var icon_1f98af535c76814ccd11afe0544b4684 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_071b0ba763bdcaebdbe6b5deb4ce3eb7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3752f3542e73e106d6f905898f89b1fa = $(`&lt;div id=&quot;html_3752f3542e73e106d6f905898f89b1fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Center&lt;/div&gt;`)[0];
#                 popup_071b0ba763bdcaebdbe6b5deb4ce3eb7.setContent(html_3752f3542e73e106d6f905898f89b1fa);
#
#
#
#         marker_96fad15a2a1313c05a3e14d45f351729.bindPopup(popup_071b0ba763bdcaebdbe6b5deb4ce3eb7)
#         ;
#
#
#
#
#                 marker_96fad15a2a1313c05a3e14d45f351729.setIcon(icon_1f98af535c76814ccd11afe0544b4684);
#
#
#             var circle_0e49883ffb924c2d9af62f0ecce0f8b4 = L.circle(
#                 [51.515, -0.11],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a793e46dc471d5b2b9528835ce7ca88a);
#
#
#             tile_layer_9b1b1791910e07b9fd75dd3a8cd34737.addTo(map_a793e46dc471d5b2b9528835ce7ca88a);
#
#
#                 marker_96fad15a2a1313c05a3e14d45f351729.setIcon(icon_1f98af535c76814ccd11afe0544b4684);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
